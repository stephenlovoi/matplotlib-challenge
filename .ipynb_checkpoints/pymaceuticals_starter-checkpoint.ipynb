# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study_df = pd.merge(mouse_metadata, study_results, 
                          how="outer", on="Mouse ID")

# Display the data table for preview
mouse_study_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_count = len(mouse_study_df["Mouse ID"].value_counts())
print(f"Number of Mice: {mice_count}")
# Out:
# Number of Mice: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_study_df["Mouse ID"].value_counts()
# Out:
# g989    13
# o926    10
# g497    10
# h246    10
# j119    10
#         ..
# o848     1
# x336     1
# t573     1
# x226     1
# n482     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID. 
g989_mouse = mouse_study_df.loc[mouse_study_df["Mouse ID"] == "g989", :]

g989_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_df = mouse_study_df[mouse_study_df['Mouse ID'] != 'g989']
clean_mouse_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#Drop rows where 'Mouse ID' only appears once

# %%
# Checking the number of mice in the clean DataFrame.
new_mice_count = len(clean_mouse_df["Mouse ID"].value_counts())
print(f"New Number of Mice: {new_mice_count}")
# Out:
# New Number of Mice: 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
grouped_regimen_df = clean_mouse_df.groupby(["Drug Regimen"])

tumor_volume = grouped_regimen_df["Tumor Volume (mm3)"]

regimen_mean = tumor_volume.mean()

regimen_median = tumor_volume.median()

regimen_variance = tumor_volume.var()

regimen_std = tumor_volume.std()

regimen_sem = tumor_volume.sem()

# Assemble the resulting series into a single summary dataframe.
summary_stats_df = pd.DataFrame({"Mean Tumor Volume (mm3)": regimen_mean, "Median Tumor Volume (mm3)": regimen_median, 
                                "Variance of Tumor Volume (mm3)": regimen_variance, "Std. Dev.of Tumor Volume (mm3)": regimen_std, 
                                "SEM of Tumor Volume (mm3)": regimen_sem})
summary_stats_df
# Out:
#               Mean Tumor Volume (mm3)  Median Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                   40.675741                  41.557809
# Ceftamin                    52.591172                  51.776157
# Infubinol                   52.884795                  51.820584
# Ketapril                    55.235638                  53.698743
# Naftisol                    54.331565                  52.509285
# Placebo                     54.033581                  52.288934
# Propriva                    52.320930                  50.446266
# Ramicane                    40.216745                  40.673236
# Stelasyn                    54.233149                  52.431737
# Zoniferol                   53.236507                  51.818479
#
#               Variance of Tumor Volume (mm3)  Std. Dev.of Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                          24.947764                        4.994774
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

summary_stats_2_df = clean_mouse_df.groupby('Drug Regimen').agg(['mean', 'median', 'var', 'std', 'sem'])["Tumor Volume (mm3)"]
summary_stats_2_df
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
drug_regimen = pd.DataFrame(clean_mouse_df.groupby(["Drug Regimen"]).count()["Mouse ID"])
drug_regimen.plot(kind = 'bar', color = 'b', figsize = (10, 3), legend = False)


plt.xlabel("Drug Regimen")
plt.ylabel("Count")
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
x_axis = np.arange(len(drug_regimen))
y_axis = drug_regimen["Mouse ID"]

plt.bar(x_axis, y_axis, color = 'r', alpha = 0.7, align = 'center')
bar_tick_locations = [value for value in x_axis]
plt.xticks(bar_tick_locations, drug_regimen.index, rotation=90)
plt.show()

# %%
# New dataframe for mouse gender
mouse_gender = mouse_metadata.groupby("Sex").count()
mouse_gender
# Out:
#         Mouse ID  Drug Regimen  Age_months  Weight (g)
# Sex
# Female       124           124         124         124
# Male         125           125         125         125

# %%
mouse_gender_df = mouse_gender.drop(columns = ['Drug Regimen', 'Age_months', 'Weight (g)'])
mouse_gender_df
# Out:
#         Mouse ID
# Sex
# Female       124
# Male         125

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

gender_colors = ['blue', 'red']

mouse_gender_df.plot(kind = 'pie', legend = False, colors = gender_colors, subplots = True, autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
which_gender = np.arange(len(mouse_gender_df))
gender_count = mouse_gender_df["Mouse ID"]

print(which_gender)
print(gender_count)
# Out:
# [0 1]
# Sex
# Female    124
# Male      125
# Name: Mouse ID, dtype: int64

# %%
which_gender_list = ["Female", "Male"]
plt.pie(gender_count, labels = which_gender_list, autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin


# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
cap_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Capomulin"]
ram_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Ramicane"]
inf_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Infubinol"]
ceft_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Ceftamin"]

cap_df.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0

# %%
#Capomulin

# Start by getting the last (greatest) timepoint for each mouse
cap_time = cap_df.groupby('Mouse ID').max()['Timepoint']
cap_time_df = pd.DataFrame(cap_time)
cap_time_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
cap_merge_df = pd.merge(cap_time_df, clean_mouse_df, on=("Mouse ID", 'Timepoint'), how='outer')
cap_merge_df.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     b128         45    Capomulin  Female           9          22
# 1     b742         45    Capomulin    Male           7          21
# 2     f966         20    Capomulin    Male          16          17
# 3     g288         45    Capomulin    Male           3          19
# 4     g316         45    Capomulin  Female          22          22
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           30.485985                 0
# 3           37.074024                 1
# 4           40.159220                 2

# %%
#Ramicane

# Start by getting the last (greatest) timepoint for each mouse
ram_time = ram_df.groupby('Mouse ID').max()['Timepoint']
ram_time_df = pd.DataFrame(ram_time)
ram_time_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
ram_merge_df = pd.merge(ram_time_df, cap_merge_df, on=("Mouse ID", 'Timepoint'), how='outer')
ram_merge_df.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     a411         45     Ramicane    Male           3          22
# 1     a444         45     Ramicane  Female          10          25
# 2     a520         45     Ramicane    Male          13          21
# 3     a644         45     Ramicane  Female           7          17
# 4     c458         30     Ramicane  Female          23          20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.407618                 1
# 1           43.047543                 0
# 2           38.810366                 1
# 3           32.978522                 1
# 4           38.342008                 2

# %%
#Infubinol

# Start by getting the last (greatest) timepoint for each mouse
inf_time = inf_df.groupby('Mouse ID').max()['Timepoint']
inf_time_df = pd.DataFrame(inf_time)
inf_time_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
inf_merge_df = pd.merge(inf_time_df, ram_merge_df, on=("Mouse ID", 'Timepoint'), how='outer')
inf_merge_df.head(5)
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     a203         45    Infubinol  Female          20          23
# 1     a251         45    Infubinol  Female          21          25
# 2     a577         30    Infubinol  Female           6          25
# 3     a685         45    Infubinol    Male           8          30
# 4     c139         45    Infubinol    Male          11          28
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           67.973419                 2
# 1           65.525743                 1
# 2           57.031862                 2
# 3           66.083066                 3
# 4           72.226731                 2

# %%
#Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
ceft_time = ceft_df.groupby('Mouse ID').max()['Timepoint']
ceft_time_df = pd.DataFrame(ceft_time)
ceft_time_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
ceft_merge_df = pd.merge(ceft_time_df, inf_merge_df, on=("Mouse ID", 'Timepoint'), how='outer')
ceft_merge_df
# Out:
#      Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0        a275         45     Ceftamin  Female          20          28
# 1        b447          0     Ceftamin    Male           2          30
# 2        b487         25     Ceftamin  Female           6          28
# 3        b759         30     Ceftamin  Female          12          25
# 4        f436         15     Ceftamin  Female           3          25
# ...       ...        ...          ...     ...         ...         ...
# 1875     z969         25     Naftisol    Male           9          30
# 1876     z969         30     Naftisol    Male           9          30
# 1877     z969         35     Naftisol    Male           9          30
# 1878     z969         40     Naftisol    Male           9          30
# 1879     z969         45     Naftisol    Male           9          30
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              62.999356                 3
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
regimen_treatment = ceft_merge_df['Drug Regimen'].tolist()

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for drug in regimen_treatment:
    tumor_vol.append(ceft_merge_df['Tumor Volume (mm3)'])
    
    # add subset 
regimen_volume_dict = {'Treatment': regimen_treatment, 
                 'Tumor Volume (mm3)': tumor_vol}

regimen_volume_df = pd.DataFrame(regimen_volume_dict)
    
    # Determine outliers using upper and lower bounds
regimen_volume_df
# Out:
#      Treatment                                 Tumor Volume (mm3)
# 0     Ceftamin  0       62.999356
# 1       45.000000
# 2       56...
# 1     Ceftamin  0       62.999356
# 1       45.000000
# 2       56...
# 2     Ceftamin  0       62.999356
# 1       45.000000
# 2       56...
# 3     Ceftamin  0       62.999356
# 1       45.000000
# 2       56...
# 4     Ceftamin  0       62.999356
# 1       45.000000
# 2       56...
# ...        ...                                                ...
# 1875  Naftisol  0       62.999356
# 1       45.000000
# 2       56...
# 1876  Naftisol  0       62.999356
# 1       45.000000
# 2       56...
# 1877  Naftisol  0       62.999356
# 1       45.000000
# 2       56...
# 1878  Naftisol  0       62.999356
# 1       45.000000
# 2       56...
# 1879  Naftisol  0       62.999356
# 1       45.000000
# 2       56...
#
# [1880 rows x 2 columns]

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
